# %%
print("Hello")
# Out:
# Hello

# %%
print("one")
print("two")
print("three")
# Out:
# one
# two
# three

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in C:\Users\MAHAVIR\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\MAHAVIR\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openpyxl) (2.0.0)

# %%
data = pd.read_excel('applications.xlsx')
print(data)

print(data.isnull().sum())
# Out:
#     Sr No    Name      Mobile        Email  Points  Percentage
# 0       1     Raj  8514860022      a@b.com     144          28
# 1       2     Ram  6786184499      x@y.com     504          84
# 2       3   Shyam  6324253106      g@h.com     521          97
# 3       4    Sita  8400305905      i@j.com     320          57
# 4       5    Gita  2320318473      m@n.com     120          19
# 5       6  Saloni  4978715481      y@z.com     168          25
# 6       7  Ramesh  7108842647      d@j.com     240          48
# 7       8  Prabha  6608133704      i@m.com     368          62
# 8       9  Vishnu  7629747921      l@m.com     522          90
# 9      10   Nayan  9897771349      i@k.com     496          97
# 10     11  Kinjal  8255012319      t@t.com     140          29
# 11     12   Priya  8058272103      o@q.com     311          60
# 12     13   Pooja  9334290602      r@j.com     475          87
# 13     14    Ravi  6388968597      d@o.com     152          31
# 14     15  Kishan  8306689853      a@v.com     329          55
# 15     16   Kirit  8866662662  k@gmail.com     400          75
# Sr No         0
# Name          0
# Mobile        0
# Email         0
# Points        0
# Percentage    0
# dtype: int64

# %%
plt.scatter(data['Points'],data['Percentage'])
plt.show()

# %%
km = KMeans(n_custers = 3)
cluster = km.fit_predict(data[['Points','Percentage']])
print(cluster)

# %%
data1 = data[data.cluster == 0]
data2 = data[data.cluster == 1]
data3 = data[data.cluster == 2]
print(data1)
print(data2)
print(data3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6648\1311455149.py in ?()
# ----> 1 data1 = data[data.cluster == 0]
#       2 data2 = data[data.cluster == 1]
#       3 data3 = data[data.cluster == 2]
#       4 print(data1)
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cluster'

# %%
plt.scatter(data1['Points'],data1['Percentage'],color = 'green')
plt.scatter(data2['Points'],data2['Percentage'],color = 'red')
plt.scatter(data3['Points'],data3['Percentage'],color = 'yellow')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plt.scatter(data1['Points'],data1['Percentage'],color = 'green')
#       2 plt.scatter(data2['Points'],data2['Percentage'],color = 'red')
#       3 plt.scatter(data3['Points'],data3['Percentage'],color = 'yellow')
#
# NameError: name 'data1' is not defined
